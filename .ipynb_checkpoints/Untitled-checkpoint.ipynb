# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

# %%
car = pd.read_csv('quikr_car (2).csv')

# %%
car.shape

# %%
car.info()

# %%
backup=car.copy()

# %% [markdown]
# ## Quality
# names are pretty inconsistent
# names have company names attached to it
# some names are spam like 'Maruti Ertiga showroom condition with' and 'Well mentained Tata Sumo'
# company: many of the names are not of any company like 'Used', 'URJENT', and so on.
# year has many non-year values
# year is in object. Change to integer
# Price has Ask for Price
# Price has commas in its prices and is in object
# kms_driven has object values with kms at last.
# It has nan values and two rows have 'Petrol' in them
# fuel_type has nan values
# Cleaning Data
# year has many non-year values

# %%
car=car[car['year'].str.isnumeric()]

# %% [raw]
# ##year is in object. Change to integer

# %%
car['year']=car['year'].astype(int)

# %%
car=car[car['Price']!='Ask For Price']

# %%
car['Price']=car['Price'].str.replace(',','').astype(int)

# %%
car['kms_driven']=car['kms_driven'].str.split().str.get(0).str.replace(',','')

# %%
car=car[car['kms_driven'].str.isnumeric()]

# %%
car['kms_driven']=car['kms_driven'].astype(int)

# %%
car=car[~car['fuel_type'].isna()]

# %%
car.shape

# %% [markdown]
# ## name and company had spammed data...but with the previous cleaning, those rows got removed.
# ##
# Company does not need any cleaning now. Changing car names. Keeping only the first three word s

# %%
car['name']=car['name'].str.split().str.slice(start=0,stop=3).str.join(' ')

# %% [markdown]
# ## Resetting the index of the final cleaned data

# %%
car=car.reset_index(drop=True)

# %% [markdown]
# ## Cleaned data

# %%
car

# %%
car.to_csv('Cleaned_Car_data.csv')

# %%
car.info()

# %%
car.describe(include='all')

# %%
car=car[car['Price']<6000000]

# %% [markdown]
# ##Checking relationship of Company with Price

# %%
car['company'].unique()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set(style="whitegrid", context="notebook")
fig, ax = plt.subplots(figsize=(15, 7))

palette = sns.color_palette("Set2")
sns.boxplot(
    x='company',
    y='Price',
    data=car,
    hue='company',
    palette=palette,
    ax=ax,
    showfliers=True,
    dodge=False
)

# ✅ Safely remove the legend
if ax.get_legend() is not None:
    ax.get_legend().remove()

# Rotate and format tick labels
for label in ax.get_xticklabels():
    label.set_rotation(40)
    label.set_ha('right')
    label.set_fontsize(10)

# Annotate medians
grouped = car.groupby('company')['Price'].median().reset_index()
for i, row in grouped.iterrows():
    ax.text(i, row['Price'], f"{row['Price']:.0f}", 
            ha='center', va='bottom', fontsize=9, color='black')

# Add grid, labels, and title
ax.set_title('Car Prices by Company', fontsize=16, weight='bold')
ax.set_xlabel('Company', fontsize=12)
ax.set_ylabel('Price (in ₹)', fontsize=12)
ax.grid(True, which='major', axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Checking relationship of Year with Price

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Set plot style and aesthetics
sns.set(style="whitegrid", context="notebook", palette="deep")

# Remove outliers based on IQR (Interquartile Range) for better data representation
Q1 = car['Price'].quantile(0.25)
Q3 = car['Price'].quantile(0.75)
IQR = Q3 - Q1
car_clean = car[(car['Price'] >= (Q1 - 1.5 * IQR)) & (car['Price'] <= (Q3 + 1.5 * IQR))]

# Create the figure with two subplots: Swarmplot + Distribution
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

# Swarmplot for individual data points
sns.swarmplot(
    x='year',
    y='Price',
    data=car_clean,
    size=4,
    color='mediumslateblue',
    alpha=0.7,
    ax=ax1,
    label='Car Prices'
)

# Optional: Overlay mean price per year using pointplot
mean_prices = car_clean.groupby('year')['Price'].mean().reset_index()
sns.pointplot(
    x='year',
    y='Price',
    data=mean_prices,
    color='darkorange',
    markers='D',
    linestyles='--',
    scale=1.2,
    label='Mean Price',
    ax=ax1
)

# Add title and labels
ax1.set_title('Car Prices by Year (Cleaned Data)', fontsize=18, weight='bold')
ax1.set_xlabel('Year', fontsize=14)
ax1.set_ylabel('Price (in ₹)', fontsize=14)

# Rotate x-tick labels
for label in ax1.get_xticklabels():
    label.set_rotation(40)
    label.set_ha('right')
    label.set_fontsize(10)

# Highlighting outliers (with a different color)
outliers = car[~car.index.isin(car_clean.index)]
sns.swarmplot(
    x='year',
    y='Price',
    data=outliers,
    size=6,
    color='red',
    alpha=0.5,
    ax=ax1,
    label='Outliers'
)

# Add a vertical line to mark the mean price
mean_price_all = car['Price'].mean()
ax1.axhline(mean_price_all, color='gray', linestyle=':', linewidth=2, label=f"Overall Mean: ₹{mean_price_all:,.0f}")

# Second subplot for the distribution of car prices (Violin Plot)
sns.violinplot(
    x='year',
    y='Price',
    data=car_clean,
    inner="quart",
    ax=ax2,
    palette='viridis',
    hue='year',  # Set hue to 'year' to match the palette
    split=True,  # Split the plot based on 'year'
    legend=False  # Disable legend for now
)
ax2.set_title('Price Distribution by Year', fontsize=18, weight='bold')
ax2.set_xlabel('Year', fontsize=14)
ax2.set_ylabel('Price (in ₹)', fontsize=14)

# Format y-axis with thousands separator
ax1.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, _: f'₹{int(x):,}'))
ax2.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, _: f'₹{int(x):,}'))

# Add grids
ax1.grid(axis='y', linestyle='--', alpha=0.5)
ax2.grid(axis='y', linestyle='--', alpha=0.5)

# Add legends manually
ax1.legend(loc='upper left', fontsize=10)
ax2.legend(loc='upper left', fontsize=10, labels=['Price Distribution', 'Outliers'])

# Tight layout to prevent overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Checking relationship of kms_driven with Price

# %%
sns.relplot(x='kms_driven',y='Price',data=car,height=7,aspect=1.5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# Set plot style
sns.set(style="whitegrid", context="notebook")

# Create the figure
plt.figure(figsize=(20, 10))

# Scatter plot with regression line
sns.regplot(
    x='kms_driven', 
    y='Price', 
    data=car, 
    scatter_kws={'s': 50, 'color': 'mediumslateblue', 'alpha': 0.7},  # Customize scatter plot
    line_kws={'color': 'red', 'linewidth': 2, 'linestyle': '--'},  # Customize regression line
    fit_reg=True  # Add regression line
)

# Add custom annotations if required (for highlighting specific points)
# Example: Annotate the top 5 highest prices
top_5_expensive = car.nlargest(5, 'Price')
for idx, row in top_5_expensive.iterrows():
    plt.text(
        row['kms_driven'], 
        row['Price'], 
        f'{row["company"]}', 
        color='black', 
        fontsize=12, 
        ha='right', 
        va='bottom'
    )

# Customize labels and title
plt.title('Car Price vs Kilometers Driven (with Regression Line)', fontsize=18, weight='bold')
plt.xlabel('Kilometers Driven', fontsize=14)
plt.ylabel('Price (in ₹)', fontsize=14)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.5)

# Rotate x-axis labels for readability
plt.xticks(rotation=45, ha='right')

# Format y-axis with thousands separator
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, _: f'₹{int(x):,}'))

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Checking relationship of Fuel Type with Price

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='fuel_type',y='Price',data=car)
# Out:
# <Axes: xlabel='fuel_type', ylabel='Price'>

# %% [markdown]
# ## Relationship of Price with FuelType, Year and Company mixed

# %%
ax=sns.relplot(x='company',y='Price',data=car,hue='fuel_type',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %% [markdown]
# ## Extracting Training Data

# %%
X=car[['name','company','year','kms_driven','fuel_type']]
y=car['Price']

# %%
X
# Out:
#                        name   company  year  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014       36000    Diesel
# 4                 Ford Figo      Ford  2012       41000    Diesel
# ..                      ...       ...   ...         ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011       50000    Petrol
# 812          Tata Indica V2      Tata  2009       30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009      132000    Petrol
# 814            Tata Zest XM      Tata  2018       27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013       40000    Diesel
#
# [815 rows x 5 columns]

# %%
y
# Out:
# 0       80000
# 1      425000
# 2      325000
# 3      575000
# 4      175000
#         ...
# 811    270000
# 812    110000
# 813    300000
# 814    260000
# 815    390000
# Name: Price, Length: 815, dtype: int32

# %% [markdown]
# ## Applying Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %% [markdown]
# ## Creating an OneHotEncoder object to contain all the possible categories

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %% [markdown]
# ##Creating a column transformer to transform categorical columns

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                    remainder='passthrough')

# %% [markdown]
# ## Linear Regression Model

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %% [markdown]
# ## Making a pipeline

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %% [markdown]
# ## fitting the model

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
y_pred=pipe.predict(X_test)

# %% [markdown]
# ## Checking R2 Score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6787767149588082

# %% [raw]
# ##Finding the model with a random state of TrainTestSplit where the model was found to give almost 0.92 as r2_score

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 302

# %%
scores[np.argmax(scores)]
# Out:
# 0.8991157554877304

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([430301.37134528])

# %% [markdown]
# ## The best model is found at a certain random state

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8991157554877304

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type'],data=np.array(['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([456670.3272301])

# %%
pipe.steps[0][1].transformers[0][1].categories[0]
# Out:
# array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#        'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#        'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#        'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#        'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#        'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#        'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#        'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#        'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#        'Ford EcoSport Titanium', 'Ford EcoSport Trend',
# ...
